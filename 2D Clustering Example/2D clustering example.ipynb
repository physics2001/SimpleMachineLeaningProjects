# %%
import numpy as np
import pandas as pd
import statsmodels as statsmodels
import seaborn as sns
from sklearn.cluster import KMeans
from sklearn.cluster import AgglomerativeClustering
import joblib
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import axes3d

data = pd.read_csv('./xclara.csv')
print(data)
# Out:
#       Unnamed: 0         V1         V2
# 0              1   2.072345  -3.241693
# 1              2  17.936710  15.784810
# 2              3   1.083576   7.319176
# 3              4  11.120670  14.406780
# 4              5  23.711550   2.557729
# ...          ...        ...        ...
# 2995        2996  85.652800  -6.461061
# 2996        2997  82.770880  -2.373299
# 2997        2998  64.465320 -10.501360
# 2998        2999  90.722820 -12.255840
# 2999        3000  64.879760 -24.877310
#
# [3000 rows x 3 columns]

# %%
data = data.drop(columns=['Unnamed: 0'])
print(data)
# Out:
#              V1         V2
# 0      2.072345  -3.241693
# 1     17.936710  15.784810
# 2      1.083576   7.319176
# 3     11.120670  14.406780
# 4     23.711550   2.557729
# ...         ...        ...
# 2995  85.652800  -6.461061
# 2996  82.770880  -2.373299
# 2997  64.465320 -10.501360
# 2998  90.722820 -12.255840
# 2999  64.879760 -24.877310
#
# [3000 rows x 2 columns]

# %%
plt.plot(data['V1'], data['V2'], 'ro')

# %%
km = KMeans(n_clusters=3, algorithm='full', max_iter=1000).fit(data)
plt.scatter(data['V1'], data['V2'], c=km.labels_, cmap='rainbow')

# %%
hc = AgglomerativeClustering(n_clusters=3).fit(data)
plt.scatter(data['V1'], data['V2'], c=hc.labels_, cmap='rainbow')
